# %% [markdown]
# # TITLE: PERFORM DATA WRANGLING AND ETL PROCESSES ON A DATASET, FOLLOWED BY EXPLORATORY DATA ANALYSIS(EDA)
# ## 1.1 THEORY
# ### Data Wrangling
# ##### Data wrangling is the process of converting raw data into a usable form. It may also be called data munging or data remediation. It describes a series of processes designed to explore, transform, and validate raw datasets from their messy and complex forms into high-quality data. We can use our wrangled data to produce valuable insights and guide business decisions.
# ##### Data wrangling steps are systematic stages in transforming raw data into a structured, clean and usable format for analysis. These steps ensure accurate and actionable insights for decision making by addressing raw data's challenges and improving it's usability.
# #### Data Wrangling Steps
# ##### **1. Discovery**
# ##### Discovery refers to the process of familiarizing with data so we can conceptualize how we might use it. We can liken it to looking in our refrigerator before cooking a meal to see what ingredients we have at our disposal.During discovery, we may identify trends or patterns in the data, along with obvious issues, such as missing or incomplete values that need to be addressed. This is an important step, as it will inform every activity that comes afterward.
# ##### **2. Structuring**
# ##### Raw data is typically unusable in its raw state because it’s either incomplete or misformatted for its intended application. Data structuring is the process of taking raw data and transforming it to be more readily leveraged. The form our data takes will depend on the analytical model we use to interpret it.
# ##### **3. Cleaning**
# ##### Data cleaning is the process of removing inherent errors in data that might distort the analysis or render it less valuable. Cleaning can come in different forms, including deleting empty cells or rows, removing outliers, and standardizing inputs. The goal of data cleaning is to ensure there are no errors (or as few as possible) that could influence the final analysis. Identifying and removing any bad data greatly impacts the rest of the wrangling processes.
# ##### **4. Enriching**
# ##### Enrichment involves adding value to our data by incorporating additional context or merging it with other relevant datasets. This can include combining data from various sources to create new variables or applying domain-specific transformations. For eg: Enrichment could involve segmenting customers into a dataset based on their purchasing behaviour.
# ##### **5. Validation**
# ##### Data validation involves ensuring the accuracy and reliability of your dataset through systematic checks and automated processes. This step is critical for confirming that data is both correct and consistent. Its goal is to catch any issues before the data is used for analysis, preventing errors from impacting the results.
# ##### **6. Data Publishing**
# ##### The final step of data wrangling involves storing the cleared and structured data in a readily accessible format for analysis. This may involve storing data in a database, data warehouse or analytics platform. It also involves documenting data with metadata detailing its content, structure and any transformation it has undergone.
#
# ### Data Transformation and Normalization Techniques
# ##### **Min-Max Transformation**
# ##### The main purpose of this transformation is it is used when the data has no outliers and if we want to scale it to a specific range[0, 1] for algorithms sensitive to scale, such as K-Nearest Neighbours(K-NN) and Neural Networks.
# ##### **Z-Score Normalization**
# ##### It is used when the data has outliers or when features have different units. Suitable for algorithms like sum and logistic regression.
#
# ## Exploratory Data Analysis(EDA)
# ##### Exploratory Data Analysis (EDA) is the initial step in the data analysis process where analysts use statistical and visualization techniques to understand the main characteristics of a dataset. The goal is to summarize its key features, discover patterns, identify anomalies, check assumptions, and test hypotheses. EDA is often used before applying machine learning models or other advanced analytical techniques to ensure the data is clean, well-understood, and ready for further analysis.
#  ### Key Steps in Exploratory Data Analysis
#  ##### **1. Understand the Data Structure:**
#  - Data types: Identify and inspect data types for each feature (numerical, categorical, datetime, etc.).
#  - Basic summary statistics: Calculate key metrics like mean, median, mode, standard deviation, and percentiles
#  - Data shape: Check the number of rows (observations) and columns (features) in the dataset.
# ##### **2. Data CLeaning:**
# - Data cleaning is the process of removing inherent errors in data that might distort the analysis or render it less valuable.
# -  Cleaning can come in different forms, including deleting empty cells or rows, removing outliers, and standardizing inputs.
# ##### **3. Univariate Analysis (Single Variable):**
# - Histograms/Bar plots: Visualize the distribution of a single feature. For continuous variables, histograms are useful, while for categorical data, bar plots can be used.
# - Box plots: Used to detect outliers and understand the spread of data. For numerical features, they show the median, quartiles, and outliers.
# - Summary statistics: Review the mean, median, mode, range, and standard deviation to understand central tendencies and variability.
# ##### **4. Bivariate Analysis (Two Variables):**
# - Scatter plots: Used to explore relationships between two continuous variables, especially for detecting trends or correlations.
# - Correlation matrix: For numerical features, calculating correlation coefficients (like Pearson or Spearman) can help identify relationships between variables.
#  ##### **5. Multivariate Analysis (Multiple Variables):**
#  - Heatmaps: A heatmap of a correlation matrix can provide a compact view of how multiple features are correlated.
#  - Principal Component Analysis (PCA): PCA is used for dimensionality reduction to find underlying patterns in data and visualize high-dimensional data in fewer dimensions.
#  - Cluster analysis: Grouping similar data points together using clustering algorithms like k-means or hierarchical clustering.
# ##### **6. Identify Outliers and Anomalies:**
# - Use statistical methods (like Z-scores) or visualization techniques (box plots, scatter plots) to detect outliers or anomalous data points that may need to be addressed.
# ##### **7. Feature Engineering:**
# - Generate new features that might help in analysis or model performance (e.g., combining existing features, transforming data types, etc.).
# ##### **8. Data Visualization:**
# - Histograms, bar charts, box plots: For univariate analysis.
# - Scatter plots, line plots: For bivariate relationships.
# - Heatmaps, pair plots: For multivariate exploration.
# - Visualizing your data helps identify patterns and potential relationships that might not be obvious from just summary statistics.
# ##### **9.Testing Assumptions:**
# - Based on the data, test assumptions that might be relevant for future analyses (e.g., checking if data is normally distributed, verifying if certain relationships hold true across different variables).
#
# ### Importance of Exploratory Data Analysis(EDA)
# ##### **Understanding the Data:**
# - Before diving into more advanced analysis, EDA allows you to understand the underlying structure of your data, the relationships between variables, and the distribution of your data.
#
# ##### **Data Quality Checks:**
# - EDA helps identify data quality issues such as missing values, outliers, duplicates, or incorrect data types. Addressing these issues is crucial for accurate analysis.
#
# ##### **Identifying Patterns and Trends:**
# - Through visualization and statistical analysis, EDA reveals patterns, correlations, and potential relationships that can inform modeling or decision-making.
#
# ##### **Hypothesis Generation:**
# - By exploring the data, you can generate hypotheses that can later be tested with more formal statistical techniques or machine learning models.
#
# ##### **Feature Selection:**
# - EDA helps in identifying the most important features for modeling by evaluating their relevance and importance. You may discard irrelevant or redundant features at this stage.

# %% [markdown]
# ## STEPS
# ###  Data Import and Header Assignment
# ##### This step involves importing raw data into the analysis environment and ensuring that the dataset has clear, meaningful headers, which is crucial for making the data easier to work with and interpret.

# %%
# Load data from URL
import pandas as pd
import numpy as np
#Define Headers 
headers = ["symboling", "normalized_losses", "make", "fuel_type", "aspiration", "num_of_doors", "body_style",
           "drive_wheels", "engine_location", "wheel_base", "length", "width", "height", "curb_weight", "engine_type",
           "num_of_cylinders", "engine_size", "fuel_system", "bore", "stroke", "compression_ratio", "horsepower",
           "peak_rpm", "city_mpg", "highway_mpg", "price"]
url = "https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DA0101EN/auto.csv"
df = pd.read_csv(url, names=headers)

# %% [markdown]
# ### Initial Data Exploration

# %%
df.head()
# Out:
#    symboling normalized_losses         make fuel_type aspiration num_of_doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Data Imputation
# ##### This step helps in identifying placeholder values (such as '?') that represent missing or undefined data and replacing them with NaN, which is a standard representation of missing values.

# %%
df.replace('?', np.nan, inplace = True)

# %% [markdown]
# ## Post-Imputation Data Inspection

# %%
df.head()
# Out:
#    symboling normalized_losses         make fuel_type aspiration num_of_doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          3               NaN  alfa-romero       gas        std          two
# 2          1               NaN  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_size  \
# 0  convertible          rwd           front        88.6  ...          130
# 1  convertible          rwd           front        88.6  ...          130
# 2    hatchback          rwd           front        94.5  ...          152
# 3        sedan          fwd           front        99.8  ...          109
# 4        sedan          4wd           front        99.4  ...          136
#
# ...

# %% [markdown]
# ### Data Summary
# ##### Provides the information of the datasets.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num_of_doors       203 non-null    object
#  6   body_style         205 non-null    object
#  7   drive_wheels       205 non-null    object
#  8   engine_location    205 non-null    object
#  9   wheel_base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %% [markdown]
# ### Ensuring Correct Data Types
# ##### This step ensures that columns which are meant to be numeric are correctly interpreted as numeric data types rather than strings or objects.

# %%
#Convert numeric columns to appropriate data types
numeric_columns = ["normalized_losses", "stroke", "horsepower", "peak_rpm", "price"]
df[numeric_columns] = df[numeric_columns].apply(pd.to_numeric)

# %% [markdown]
# ###  Verifying Data Types
# ##### This step helps to verify that the data types for the columns have been correctly updated, ensuring that the changes made were applied successfully.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num_of_doors       203 non-null    object
#  6   body_style         205 non-null    object
#  7   drive_wheels       205 non-null    object
#  8   engine_location    205 non-null    object
#  9   wheel_base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_of_cylinders   205 non-null    object
# ...

# %% [markdown]
# ### Null Value Summary
# ##### This step helps quickly identify how many missing (null) values are present in each column of the dataset.

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized_losses    41
# make                  0
# fuel_type             0
# aspiration            0
# num_of_doors          2
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# ### Statistical Summary of Data

# %%
df.describe()
# Out:
#         symboling  normalized_losses  wheel_base      length       width  \
# count  205.000000         164.000000  205.000000  205.000000  205.000000
# mean     0.834146         122.000000   98.756585  174.049268   65.907805
# std      1.245307          35.442168    6.021776   12.337289    2.145204
# min     -2.000000          65.000000   86.600000  141.100000   60.300000
# 25%      0.000000          94.000000   94.500000  166.300000   64.100000
# 50%      1.000000         115.000000   97.000000  173.200000   65.500000
# 75%      2.000000         150.000000  102.400000  183.100000   66.900000
# max      3.000000         256.000000  120.900000  208.100000   72.300000
#
#            height  curb_weight  engine_size      stroke  compression_ratio  \
# count  205.000000   205.000000   205.000000  201.000000         205.000000
# mean    53.724878  2555.565854   126.907317    3.255423          10.142537
# std      2.443522   520.680204    41.642693    0.316717           3.972040
# ...

# %% [markdown]
# ### Categorical Data Summary

# %%
df.describe(include=['object'])
# Out:
#           make fuel_type aspiration num_of_doors body_style drive_wheels  \
# count      205       205        205          203        205          205
# unique      22         2          2            2          5            3
# top     toyota       gas        std         four      sedan          fwd
# freq        32       185        168          114         96          120
#
#        engine_location engine_type num_of_cylinders fuel_system  bore
# count              205         205              205         205   201
# unique               2           7                7           8    38
# top              front         ohc             four        mpfi  3.62
# freq               202         148              159          94    23

# %% [markdown]
# ### Unique Value Inspection
# ##### This step helps to identify all the unique values or categories present in a specific column

# %%
df['make'].unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'mercedes-benz', 'mercury',
#        'mitsubishi', 'nissan', 'peugot', 'plymouth', 'porsche', 'renault',
#        'saab', 'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %% [markdown]
# ### Exploring Unique Categories in Categorical Columns
# #####  This step helps to inspect the distinct categories or values in each categorical feature and ensure that each categorical column contains expected, consistent values.

# %%
# Unique values in categorical columns
categorical_columns = ["make", "fuel_type", "aspiration", "num_of_doors", "body_style", "drive_wheels"]
for col in categorical_columns:
    print(f"Unique values in {col}: {df[col].unique()}")
# Out:
# Unique values in make: ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
# Unique values in fuel_type: ['gas' 'diesel']
# Unique values in aspiration: ['std' 'turbo']
# Unique values in num_of_doors: ['two' 'four' nan]
# Unique values in body_style: ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
# Unique values in drive_wheels: ['rwd' 'fwd' '4wd']

# %% [markdown]
# # Structuring

# %% [markdown]
# ### Column Inspection

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %% [markdown]
# ### Unit Conversion and Feature Modification

# %%
# Convert MPG to L/100km
df["city_L/100km"] = 235 / df["city_mpg"].astype(float) 
df["highway_L/100km"] = 235 / df["highway_mpg"].astype(float)

# Drop original MPG columns
df.drop(columns=["city_mpg", "highway_mpg"], inplace=True)

# %% [markdown]
# # Data Standardization

# %% [markdown]
# ### Selecting Numeric Columns
# ##### This step involves selecting a subset of the DataFrame that contains only the numeric columns (as specified in the numeric_columns list).

# %%
df[numeric_columns]
# Out:
#      normalized_losses  stroke  horsepower  peak_rpm    price
# 0                  NaN    2.68       111.0    5000.0  13495.0
# 1                  NaN    2.68       111.0    5000.0  16500.0
# 2                  NaN    3.47       154.0    5000.0  16500.0
# 3                164.0    3.40       102.0    5500.0  13950.0
# 4                164.0    3.40       115.0    5500.0  17450.0
# ..                 ...     ...         ...       ...      ...
# 200               95.0    3.15       114.0    5400.0  16845.0
# 201               95.0    3.15       160.0    5300.0  19045.0
# 202               95.0    2.87       134.0    5500.0  21485.0
# 203               95.0    3.40       106.0    4800.0  22470.0
# 204               95.0    3.15       114.0    5400.0  22625.0
#
# [205 rows x 5 columns]

# %% [markdown]
# ### Feature Scaling(Data Normalization)
# ##### Z-score Standardization used to scale the features such that they have a mean of 0 and a standard deviation of 1. Min-Max Scaling transforms the numeric features into a fixed range, typically between 0 and 1.

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Z-score standardization
scaler = StandardScaler()
# Exclude price column for standardization
new_numeric_columns = [col for col in numeric_columns if col != "price"]
df_zscore = pd.DataFrame(scaler.fit_transform(df[new_numeric_columns]), columns=new_numeric_columns)
df[new_numeric_columns] = df_zscore

# Min-Max scaling
minmax_scaler = MinMaxScaler()
df_minmax = pd.DataFrame(minmax_scaler.fit_transform(df[numeric_columns]), columns=numeric_columns)
df[numeric_columns] = df_minmax

# %% [markdown]
# ### Column Name Inspection

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'price', 'city_L/100km',
#        'highway_L/100km'],
#       dtype='object')

# %% [markdown]
# ### Previewing the Data

# %%
df.head()
# Out:
#    symboling  normalized_losses         make fuel_type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2           0.518325         audi       gas        std
# 4          2           0.518325         audi       gas        std
#
#   num_of_doors   body_style drive_wheels engine_location  wheel_base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine_size  fuel_system  bore    stroke compression_ratio horsepower  \
# ...

# %%
# Replace NaN in categorical columns with the mode
df[categorical_columns] = df[categorical_columns].apply(lambda col: col.fillna(col.mode()[0]))

# %%
# One-hot encode body-style
df = pd.get_dummies(df, columns=["body_style"], drop_first=True)

# %%
df.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'drive_wheels', 'engine_location', 'wheel_base',
#        'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'price', 'city_L/100km',
#        'highway_L/100km', 'body_style_hardtop', 'body_style_hatchback',
#        'body_style_sedan', 'body_style_wagon'],
#       dtype='object')

# %% [markdown]
# ### Selecting Specific Features

# %%
df[['body_style_hardtop', 'body_style_hatchback', 'body_style_sedan', 'body_style_wagon']]
# Out:
#      body_style_hardtop  body_style_hatchback  body_style_sedan  \
# 0                 False                 False             False
# 1                 False                 False             False
# 2                 False                  True             False
# 3                 False                 False              True
# 4                 False                 False              True
# ..                  ...                   ...               ...
# 200               False                 False              True
# 201               False                 False              True
# 202               False                 False              True
# 203               False                 False              True
# 204               False                 False              True
#
#      body_style_wagon
# 0               False
# 1               False
# 2               False
# 3               False
# 4               False
# ..                ...
# 200             False
# ...

# %% [markdown]
# ### Categorical Variable Encoding
# ##### It is applied to categorical columns, transforming each category (or unique value) into a corresponding numeric label.

# %%
# Label encode fuel-type
from sklearn.preprocessing import LabelEncoder
label_enc = LabelEncoder()

for col in[col for col in categorical_columns if col != "body_style"]:
    df[col] = label_enc.fit_transform(df[col].astype(str))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 29 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   symboling             205 non-null    int64
#  1   normalized_losses     164 non-null    float64
#  2   make                  205 non-null    int32
#  3   fuel_type             205 non-null    int32
#  4   aspiration            205 non-null    int32
#  5   num_of_doors          205 non-null    int32
#  6   drive_wheels          205 non-null    int32
#  7   engine_location       205 non-null    object
#  8   wheel_base            205 non-null    float64
#  9   length                205 non-null    float64
#  10  width                 205 non-null    float64
#  11  height                205 non-null    float64
#  12  curb_weight           205 non-null    int64
#  13  engine_type           205 non-null    object
#  14  num_of_cylinders      205 non-null    object
# ...

# %% [markdown]
# # CLEANING

# %%
df.isnull().sum()
# Out:
# symboling                0
# normalized_losses       41
# make                     0
# fuel_type                0
# aspiration               0
# num_of_doors             0
# drive_wheels             0
# engine_location          0
# wheel_base               0
# length                   0
# width                    0
# height                   0
# curb_weight              0
# engine_type              0
# num_of_cylinders         0
# engine_size              0
# fuel_system              0
# bore                     4
# stroke                   4
# compression_ratio        0
# horsepower               2
# peak_rpm                 2
# price                    4
# city_L/100km             0
# highway_L/100km          0
# body_style_hardtop       0
# body_style_hatchback     0
# body_style_sedan         0
# body_style_wagon         0
# dtype: int64

# %%
df.head(5)
# Out:
#    symboling  normalized_losses  make  fuel_type  aspiration  num_of_doors  \
# 0          3                NaN     0          1           0             1
# 1          3                NaN     0          1           0             1
# 2          1                NaN     0          1           0             1
# 3          2           0.518325     1          1           0             0
# 4          2           0.518325     1          1           0             0
#
#    drive_wheels engine_location  wheel_base  length  ...  compression_ratio  \
# 0             2           front        88.6   168.8  ...                9.0
# 1             2           front        88.6   168.8  ...                9.0
# 2             2           front        94.5   171.2  ...                9.0
# 3             1           front        99.8   176.6  ...               10.0
# 4             0           front        99.4   176.6  ...                8.0
#
# ...

# %%
# Replace NAN in numeric columns with the mean, and in the categorical columns with the mode
df[numeric_columns] = df[numeric_columns].apply(lambda col: col.fillna(col.mean()))

# %%
df.head(5)
# Out:
#    symboling  normalized_losses  make  fuel_type  aspiration  num_of_doors  \
# 0          3           0.298429     0          1           0             1
# 1          3           0.298429     0          1           0             1
# 2          1           0.298429     0          1           0             1
# 3          2           0.518325     1          1           0             0
# 4          2           0.518325     1          1           0             0
#
#    drive_wheels engine_location  wheel_base  length  ...  compression_ratio  \
# 0             2           front        88.6   168.8  ...                9.0
# 1             2           front        88.6   168.8  ...                9.0
# 2             2           front        94.5   171.2  ...                9.0
# 3             1           front        99.8   176.6  ...               10.0
# 4             0           front        99.4   176.6  ...                8.0
#
# ...

# %% [markdown]
# # HANDLING OUTLIERS

# %%
df.shape
# Out:
# (205, 29)

# %%
# remove outliers using IQR
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

for column in numeric_columns:
    df = remove_outliers(df, column)

# %%
df.shape
# Out:
# (160, 29)

# %% [markdown]
# # ENRICHING
# ### FEATURE ENGINEERING
# #### Feature Creation and Binning And Categorical Encoding.
# ##### These steps are crucial for transforming and creating new features from existing ones to enhance the dataset’s ability to capture patterns and relationships, particularly for machine learning algorithms.

# %%
# Create new feature: Power-to-weight ratio
df["power_to_weight"] = df["horsepower"] / df["curb_weight"]

# Categorize price into bins
df["price_category"] = pd.cut(df["price"], bins=3, labels=["Low", "Medium", "High"])
print(df["price_category"].sample())

# Label encode the price_category column
df["price_category"] = label_enc.fit_transform(df["price_category"])
# Out:
# 89    Low
# Name: price_category, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %% [markdown]
# # Validating

# %%
df.sample(10)
# Out:
#      symboling  normalized_losses  make  fuel_type  aspiration  num_of_doors  \
# 116          0           0.502618    13          0           1             0
# 66           0           0.298429     8          0           0             0
# 53           1           0.251309     8          1           0             0
# 31           2           0.376963     5          1           0             1
# 94           1           0.329843    12          1           0             1
# 170          2           0.361257    19          1           0             1
# 161          0           0.136126    19          1           0             0
# 42           1           0.219895     5          1           0             1
# 117          0           0.502618    13          1           1             0
# 9            0           0.298429     1          1           1             1
#
#      drive_wheels engine_location  wheel_base  length  ...  peak_rpm  \
# ...

# %% [markdown]
# ### Data Type Validation
# ##### These steps(checking dublicates and validating data types) help ensure the integrity of your dataset, confirming that no duplicates are present and that the data types align with the expected values for each column. These checks are important for reliable and accurate analysis.

# %%
# Check for duplicates
print("Number of duplicate rows: {df.duplicated().sum()}")
# df.drop_duplicates(inplace=True)

# Validate data types and unique values
print("Column Data Types: \n", df.dtypes)
# Out:
# Number of duplicate rows: {df.duplicated().sum()}
# Column Data Types:
#  symboling                 int64
# normalized_losses       float64
# make                      int32
# fuel_type                 int32
# aspiration                int32
# num_of_doors              int32
# drive_wheels              int32
# engine_location          object
# wheel_base              float64
# length                  float64
# width                   float64
# height                  float64
# curb_weight               int64
# engine_type              object
# num_of_cylinders         object
# engine_size               int64
# fuel_system              object
# bore                     object
# stroke                  float64
# compression_ratio       float64
# horsepower              float64
# peak_rpm                float64
# price                   float64
# city_L/100km            float64
# highway_L/100km         float64
# body_style_hardtop         bool
# body_style_hatchback       bool
# ...

# %% [markdown]
# # EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 160 entries, 0 to 204
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   symboling             160 non-null    int64
#  1   normalized_losses     160 non-null    float64
#  2   make                  160 non-null    int32
#  3   fuel_type             160 non-null    int32
#  4   aspiration            160 non-null    int32
#  5   num_of_doors          160 non-null    int32
#  6   drive_wheels          160 non-null    int32
#  7   engine_location       160 non-null    object
#  8   wheel_base            160 non-null    float64
#  9   length                160 non-null    float64
#  10  width                 160 non-null    float64
#  11  height                160 non-null    float64
#  12  curb_weight           160 non-null    int64
#  13  engine_type           160 non-null    object
#  14  num_of_cylinders      160 non-null    object
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ### Data Visualization: Distribution Plot

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
sns.histplot(df["price"], kde=True, bins=30)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Data Visualization: Scatter Plot

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="engine_size", y="price", data=df)
plt.title("Engine Size vs Price")
plt.xlabel("Engine Size")
plt.ylabel("Price")
plt.show()

# %% [markdown]
# ### Data Visualization: Box Plot

# %%
df_reshaped = df.melt(id_vars=["price"],
                      value_vars=["body_style_hardtop", "body_style_hatchback", "body_style_sedan", "body_style_wagon"],
                      var_name="body_style", value_name="encoded")


plt.figure(figsize=(10, 6))
sns.boxplot(x="body_style", y="price", data=df_reshaped[df_reshaped["encoded"]])
plt.title("Price by Body Style")
plt.show()

# %% [markdown]
# # DISCUSSION
# ##### In this data wrangling lab, we performed a series of essential preprocessing tasks to prepare the dataset for further analysis or machine learning. The first critical step involved handling missing values, where we identified and replaced any missing data, represented by ?, with NaN. Next, we focused on transforming and standardizing the numerical features to bring them to a comparable scale. By applying Z-score standardization and Min-Max scaling, we ensured that the numerical columns were normalized, which is vital for algorithms that are sensitive to feature magnitude or scale. We also engineered a new feature, the Power-to-Weight ratio, which might offer more meaningful insights into the performance of vehicles. Additionally, we categorized the continuous price variable into bins ("Low", "Medium", "High"), which helps simplify price analysis, particularly for models that work with categorical data. Label encoding was applied to categorical variables like fuel_type and body_style, transforming them into numeric values that are machine-learning-friendly.
# ##### Furthermore, we visualized key relationships in the dataset through histograms, scatter plots, and box plots. These visualizations allowed us to uncover patterns and outliers that would otherwise be difficult to detect. The box plot of Price by Body Style further demonstrated the variability in car prices across different body styles, helping us understand the spread and central tendency for each category. These visualizations not only gave us a clearer picture of the dataset’s structure but also guided us in making data-driven decisions for further analysis or model development. Overall, this lab highlighted the significance of thorough data wrangling in preparing datasets for analysis, ensuring that we could extract meaningful insights and use the data effectively for predictive modeling.
#
# # CONCLUSION
# ##### This lab demonstrated the importance of data wrangling and feature engineering in transforming raw data into a structured, clean, and insightful format. Through various preprocessing techniques like handling missing values, scaling features, and encoding categorical variables, we prepared the dataset for further analysis or predictive modeling.
# ##### The visualizations provided crucial insights into the relationships between different features (e.g., engine_size and price, body_style and price), which will help guide the development of a machine learning model by identifying trends, outliers, and correlations. For instance, the scatter plot suggested a positive correlation between engine size and price, while the box plot revealed how different body styles affect the price distribution. Ultimately, this process highlights the significance of data preprocessing in building robust and effective models. By carefully handling data, transforming features, and visualizing relationships, we set the stage for making informed decisions based on the dataset or applying machine learning algorithms that will learn meaningful patterns from the data.
